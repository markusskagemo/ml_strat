# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)
from ordercompute import orderCompute

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])
import backtrader as bt

class SRStrategy(bt.Strategy):
    
    params = (
        ('target_q', 2),
        ('stop_q', 10)
    )
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s %s, %s' % (dt.isoformat(), self.msP.time, txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.datalow = self.datas[0].low
        self.datahigh = self.datas[0].high
        
        self.fromdate = datetime.datetime(2016, 3, 2) #
        self.order = None
        self.buyprice = None
        self.buycomm = None
        self.isImported = False #
        self.x = -1 #
        self.longtarget = 100 #
        self.longstop = 100 #
        self.shorttarget = 100 #
        self.shortstop = 100 #
        self.levelhistory = [0]*4 #
        self.opendate = self.data.datetime.date() #
        self.ordertype = None #
        
        class mshiftParams(): # > Pass msP as function instead?
            pass
        self.msP = mshiftParams() #
        self.msP.time = self.data.datetime.time(0).isoformat()
        self.msP.date = str(self.fromdate).split(' ')[0]
        self.msP.symbol = 'EURUSD'
        self.msP.quantile = 0.15
        self.msP.n_samples = 500

        self.srlevels = orderCompute(self.msP).newSR() #

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enougth cash
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            '''
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))
            '''
            self.bar_executed = len(self)

        # Write down: no pending order
        self.order = None
        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f\n' %
                 (trade.pnl, trade.pnlcomm))
    def next(self):
        self.msP.time = self.data.datetime.time().isoformat()
        self.msP.date = self.data.datetime.date().isoformat()
        
        # Recalibrate S/R at midnight
        if datetime.time(0, 1) < self.data.datetime.time() < datetime.time(0, 10) and self.isImported == False:
            self.srlevels = orderCompute(self.msP).newSR()
            self.isImported = True
        if self.data.datetime.time() == datetime.time(0, 11):
            self.isImported = False
            
        # Log the closing price of the series from the reference
        #self.log('Close, %f.4' % self.dataclose[0])

        # Check if an order is pending
        if self.order:
            return
        
        #closelevel = min(srlevels, key=lambda x:abs(x-self.dataclose[0]))
        closestlevel = orderCompute.takeClosest(self.srlevels, self.dataclose[0])
        
        # Get last relevant level touch point
        # > For live, try to get open data or OHLC to reduce requests
        if ((self.dataclose[-1] <= closestlevel <= self.dataclose[0] or 
            self.dataclose[-1] >= closestlevel >= self.dataclose[0]) and 
            self.levelhistory[0] != closestlevel):
            # remove last
            self.levelhistory.pop(3)
            # append first
            self.levelhistory.insert(0, closestlevel)
        
        # Check if we are in the market
        if (not self.position and len(self.srlevels) > 2 
            and self.dataclose[-1] != self.dataclose[0]): #or self.opendate != self.data.datetime.date():
            if (self.data.datetime.time() > datetime.time(0, 2)
                and self.ordertype == None 
                and min(self.srlevels) <= self.dataclose[0] <= max(self.srlevels)):
                
                if closestlevel != max(self.srlevels): # > redundant
                    # > Get OHLC, in this case L
                    if self.levelhistory[1] > self.levelhistory[0] and self.dataclose[0] <= self.levelhistory[0]:
                        self.longtarget = (self.srlevels[self.srlevels.index(closestlevel)+1] - 
                                         (self.srlevels[self.srlevels.index(closestlevel)+1] - self.dataclose[0])*float(self.p.target_q)/10.0)
                        self.longstop = (self.dataclose[0] - (self.srlevels[self.srlevels.index(closestlevel)+1] - 
                                                              self.dataclose[0])*float(self.p.stop_q))
                        self.opendate = self.data.datetime.date()
                        self.order = self.buy()
                        self.log('LONG CREATE, P:%.4f, T:%.4f, SL:%.4f' % (self.dataclose[0], self.longtarget, self.longstop))
                        self.ordertype = 'Long'

                if closestlevel != min(self.srlevels) and 1==2: # > redundant
                    if self.levelhistory[1] < self.levelhistory[0] and self.dataclose[0] >= self.levelhistory[0]:
                        self.shorttarget = self.dataclose[0] - (self.dataclose[0] - self.srlevels[self.srlevels.index(closestlevel)-1])*float(self.p.target_q)/10.0
                        self.shortstop = self.dataclose[0] + (self.dataclose[0] - self.shorttarget)*float(self.p.stop_q)/10.0
                        self.opendate = self.data.datetime.date()
                        self.order = self.sell()
                        self.log('SHORT CREATE, P:%.4f, T:%.4f, SL:%.4f' % (self.dataclose[0], self.shorttarget, self.shortstop))
                        self.ordertype = 'Short'
                
        else:
            # > Close 'types' of orders, not every order over/under a threshold.
            # > Ex. only one self.ordertype active /zone, but multiple orders of different direction open simultaniously.
            if self.ordertype == 'Long': # and not order.isbuy():
                if self.dataclose[0] >= self.longtarget or self.dataclose[0] <= self.longstop: #or 
                    self.log('LONG POSITION CLOSE, %.4f' % self.dataclose[0])
                    self.order = self.close()
                    self.ordertype = None
            elif self.ordertype == 'Short': #and not self.order.issell():
                if self.dataclose[0] <= self.shorttarget or self.dataclose[0] >= self.shortstop:
                    self.log('SHORT POSITION CLOSE, %.4f' % self.dataclose[0])
                    self.order = self.close()
                    self.ordertype = None
            '''
            elif self.data.datetime.time() < datetime.time(0, 2):
                self.log('POSITION FORCE CLOSE, %.4f' % self.dataclose[0])
                self.order = self.close()
                self.ordertype = None
            '''
            
if __name__ == '__main__':
    cerebro = bt.Cerebro()

    cerebro.addstrategy(SRStrategy)
    '''
    cerebro.optstrategy(
        SRStrategy,
        target_q=range(8, 12),
        stop_q=range(8, 20, 2),
    )
    '''

    #modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    #datapath = os.path.join(modpath, '../../datas/orcl-1995-2014.txt')
    datapath = 'data/tickdump/EURUSD_20160301-20170301.csv' #YHOO1617.csv'
    
    # Create a Data Feed
    data = bt.feeds.GenericCSVData(
        dataname=datapath,
        fromdate=datetime.datetime(2016, 3, 2),
        todate=datetime.datetime(2016, 4, 30),
        timeframe=bt.TimeFrame.Minutes,
        dtformat='%d.%m.%Y %H:%M:%S.000')

    cerebro.adddata(data)
    cerebro.broker.setcash(100000.0)
    print('Starting Portfolio Value: %.4f' % cerebro.broker.getvalue())
    
    cerebro.addsizer(bt.sizers.FixedSize, stake=90000)
    cerebro.broker.setcommission(commission=0.00001)
    
    # Run over everything
    cerebro.run()
    cerebro.plot()

    # Print out the final result
    print('Final Portfolio Value: %.4f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.0000
# 2016-03-02
# 2016-03-01
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_01_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0834
# 1.0856
# 1.0872
# 1.0894
#
#
# 2016-03-02
# 2016-03-01
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_01_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0834
# 1.0856
# 1.0872
# 1.0894
#
#
# 2016-03-02 05:41:00, LONG CREATE, P:1.0855, T:1.0869, SL:1.0688
# 2016-03-02 09:02:00, LONG POSITION CLOSE, 1.0872
# 2016-03-02 09:02:00, OPERATION PROFIT, GROSS 144.00, NET 142.04
#
# 2016-03-02 11:53:00, LONG CREATE, P:1.0856, T:1.0869, SL:1.0692
# 2016-03-02 19:57:00, LONG POSITION CLOSE, 1.0869
# 2016-03-02 19:57:00, OPERATION PROFIT, GROSS 120.60, NET 118.64
#
# 2016-03-03
# 2016-03-02
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_02_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0826
# 1.0842
# 1.0857
# 1.0881
#
#
# 2016-03-03 05:13:00, LONG CREATE, P:1.0857, T:1.0876, SL:1.0616
# 2016-03-03 11:09:00, LONG POSITION CLOSE, 1.0877
# 2016-03-03 11:09:00, OPERATION PROFIT, GROSS 187.20, NET 185.24
#
# 2016-03-04
# 2016-03-03
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_03_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0854
# 1.0886
# 1.0917
# 1.0944
# 1.0973
#
#
# 2016-03-04 14:33:00, LONG CREATE, P:1.0917, T:1.0939, SL:1.0643
# 2016-03-04 14:49:00, LONG POSITION CLOSE, 1.0941
# 2016-03-04 14:49:00, OPERATION PROFIT, GROSS 207.90, NET 205.93
#
# 2016-03-05
# 2016-03-04
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_04_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0904
# 1.0935
# 1.0958
# 1.0976
# 1.099
# 1.1044
#
#
# 2016-03-06
# 2016-03-04
# 2016-03-04
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_04_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0904
# 1.0935
# 1.0958
# 1.0976
# 1.099
# 1.1044
#
#
# 2016-03-07
# 2016-03-06
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_06_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0989
# 1.0998
#
#
# 2016-03-08
# 2016-03-07
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_07_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.094
# 1.0966
# 1.0985
# 1.1003
# 1.1026
#
#
# 2016-03-08 12:09:00, LONG CREATE, P:1.1003, T:1.1021, SL:1.0773
# 2016-03-08 13:28:00, LONG POSITION CLOSE, 1.1022
# 2016-03-08 13:28:00, OPERATION PROFIT, GROSS 180.00, NET 178.02
#
# 2016-03-08 19:20:00, LONG CREATE, P:1.1001, T:1.1021, SL:1.0749
# 2016-03-09
# 2016-03-08
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_08_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0994
# 1.1015
# 1.1031
# 1.1058
#
#
# 2016-03-09 17:37:00, LONG POSITION CLOSE, 1.1021
# 2016-03-09 17:37:00, OPERATION PROFIT, GROSS 185.40, NET 183.42
#
# 2016-03-09 19:47:00, LONG CREATE, P:1.1015, T:1.1028, SL:1.0854
# 2016-03-10
# 2016-03-09
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_09_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0946
# 1.0964
# 1.0989
# 1.1008
# 1.1035
#
#
# 2016-03-10 13:57:00, LONG POSITION CLOSE, 1.0851
# 2016-03-10 13:57:00, OPERATION PROFIT, GROSS -1470.60, NET -1472.57
#
# 2016-03-10 15:23:00, LONG CREATE, P:1.1007, T:1.1029, SL:1.0732
# 2016-03-10 15:25:00, LONG POSITION CLOSE, 1.1043
# 2016-03-10 15:25:00, OPERATION PROFIT, GROSS 315.00, NET 313.02
#
# 2016-03-11
# 2016-03-10
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_10_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.0822
# 1.0917
# 1.1008
# 1.1115
# 1.1218
#
#
# 2016-03-12
# 2016-03-11
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_11_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.108
# 1.1105
# 1.1128
# 1.1147
# 1.121
#
#
# 2016-03-13
# 2016-03-11
# 2016-03-11
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_11_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.108
# 1.1105
# 1.1128
# 1.1147
# 1.121
#
#
# 2016-03-14
# 2016-03-13
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_13_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1138
# 1.1149
# 1.116
# 1.1177
#
#
# 2016-03-14 02:18:00, LONG CREATE, P:1.1149, T:1.1158, SL:1.1036
# 2016-03-14 04:01:00, LONG POSITION CLOSE, 1.1158
# 2016-03-14 08:26:00, LONG CREATE, P:1.1147, T:1.1157, SL:1.1021
# 2016-03-15
# 2016-03-14
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_14_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1078
# 1.1096
# 1.111
# 1.1126
# 1.1148
# 1.1167
#
#
# 2016-03-16
# 2016-03-15
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_15_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1072
# 1.1094
# 1.1104
# 1.1125
#
#
# 2016-03-16 20:33:00, LONG POSITION CLOSE, 1.1221
# 2016-03-17
# 2016-03-16
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_16_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1058
# 1.1079
# 1.1132
# 1.1196
# 1.1242
#
#
# 2016-03-18
# 2016-03-17
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_17_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1206
# 1.1233
# 1.1282
# 1.1343
#
#
# 2016-03-19
# 2016-03-18
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_18_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1256
# 1.1281
# 1.13
# 1.132
# 1.1337
#
#
# 2016-03-20
# 2016-03-18
# 2016-03-18
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_18_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1256
# 1.1281
# 1.13
# 1.132
# 1.1337
#
#
# 2016-03-21
# 2016-03-20
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_20_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1263
# 1.1282
#
#
# 2016-03-22
# 2016-03-21
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_21_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1233
# 1.1246
# 1.1267
# 1.1285
#
#
# 2016-03-22 00:03:00, LONG CREATE, P:1.1239, T:1.1245, SL:1.1172
# 2016-03-22 03:57:00, LONG POSITION CLOSE, 1.1246
# 2016-03-23
# 2016-03-22
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_22_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1189
# 1.1229
# 1.1248
# 1.126
#
#
# 2016-03-23 00:03:00, LONG CREATE, P:1.1217, T:1.1242, SL:1.0909
# 2016-03-24
# 2016-03-23
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_23_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.116
# 1.1175
# 1.1186
# 1.1199
# 1.1211
# 1.1222
#
#
# 2016-03-25
# 2016-03-24
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_24_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1145
# 1.1162
# 1.1176
# 1.1188
#
#
# 2016-03-26
# 2016-03-25
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_25_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1154
# 1.1171
# 1.1177
#
#
# 2016-03-27
# 2016-03-25
# 2016-03-25
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_25_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1154
# 1.1171
# 1.1177
#
#
# 2016-03-28
# 2016-03-27
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_27_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1156
# 1.1167
# 1.1171
#
#
# 2016-03-29
# 2016-03-28
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_28_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1153
# 1.1182
# 1.1205
# 1.122
#
#
# 2016-03-29 19:15:00, LONG POSITION CLOSE, 1.1279
# 2016-03-30
# 2016-03-29
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_29_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1169
# 1.1224
# 1.1261
# 1.1281
# 1.1304
#
#
# 2016-03-31
# 2016-03-30
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_30_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1286
# 1.131
# 1.1328
# 1.1344
# 1.1366
#
#
# 2016-04-01
# 2016-03-30
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_03_30_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1286
# 1.131
# 1.1328
# 1.1344
# 1.1366
#
#
# 2016-04-01 15:11:00, LONG CREATE, P:1.1343, T:1.1361, SL:1.1116
# 2016-04-01 16:50:00, LONG POSITION CLOSE, 1.1375
# 2016-04-02
# 2016-04-01
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_01_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1335
# 1.1366
# 1.1387
# 1.1407
# 1.1438
#
#
# 2016-04-03
# 2016-04-01
# 2016-04-01
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_01_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1335
# 1.1366
# 1.1387
# 1.1407
# 1.1438
#
#
# 2016-04-04
# 2016-04-03
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_03_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1388
# 1.1402
#
#
# 2016-04-05
# 2016-04-04
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_04_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1358
# 1.1374
# 1.139
# 1.1413
#
#
# 2016-04-05 08:03:00, LONG CREATE, P:1.1373, T:1.1387, SL:1.1203
# 2016-04-05 18:08:00, LONG POSITION CLOSE, 1.1398
# 2016-04-06
# 2016-04-05
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_05_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1336
# 1.1352
# 1.1364
# 1.1378
# 1.1391
# 1.1405
#
#
# 2016-04-06 01:01:00, LONG CREATE, P:1.1378, T:1.1388, SL:1.1246
# 2016-04-06 14:45:00, LONG POSITION CLOSE, 1.1393
# 2016-04-06 15:35:00, LONG CREATE, P:1.1375, T:1.1388, SL:1.1213
# 2016-04-06 18:09:00, LONG POSITION CLOSE, 1.1418
# 2016-04-07
# 2016-04-06
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_06_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1327
# 1.136
# 1.1376
# 1.1388
# 1.1406
# 1.1432
#
#
# 2016-04-07 08:41:00, LONG CREATE, P:1.1386, T:1.1402, SL:1.1191
# 2016-04-08
# 2016-04-07
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_07_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1338
# 1.1383
# 1.1394
# 1.1408
# 1.1432
# 1.1454
#
#
# 2016-04-08 16:19:00, LONG POSITION CLOSE, 1.1409
# 2016-04-08 19:24:00, LONG CREATE, P:1.1394, T:1.1405, SL:1.1254
# 2016-04-09
# 2016-04-08
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_08_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1349
# 1.1371
# 1.1382
# 1.1393
# 1.142
#
#
# 2016-04-10
# 2016-04-08
# 2016-04-08
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_08_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1349
# 1.1371
# 1.1382
# 1.1393
# 1.142
#
#
# 2016-04-10 22:01:00, LONG POSITION CLOSE, 1.1414
# 2016-04-11
# 2016-04-10
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_10_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1401
# 1.1416
# 1.1421
#
#
# 2016-04-11 02:51:00, LONG CREATE, P:1.1416, T:1.1420, SL:1.1363
# 2016-04-11 14:57:00, LONG POSITION CLOSE, 1.1441
# 2016-04-11 17:25:00, LONG CREATE, P:1.1414, T:1.1420, SL:1.1344
# 2016-04-12
# 2016-04-11
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_11_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1373
# 1.1399
# 1.1424
# 1.1448
#
#
# 2016-04-12 07:59:00, LONG POSITION CLOSE, 1.1420
# 2016-04-12 10:07:00, LONG CREATE, P:1.1422, T:1.1443, SL:1.1163
# 2016-04-13
# 2016-04-12
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_12_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1346
# 1.138
# 1.1398
# 1.143
# 1.1465
#
#
# 2016-04-14
# 2016-04-13
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_13_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1268
# 1.1294
# 1.1331
# 1.1362
# 1.1391
#
#
# 2016-04-15
# 2016-04-14
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_14_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1234
# 1.1254
# 1.1271
# 1.1284
# 1.1295
#
#
# 2016-04-16
# 2016-04-15
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_15_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1246
# 1.1269
# 1.1281
# 1.1292
# 1.1302
# 1.1317
#
#
# 2016-04-17
# 2016-04-15
# 2016-04-15
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_15_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1246
# 1.1269
# 1.1281
# 1.1292
# 1.1302
# 1.1317
#
#
# 2016-04-18
# 2016-04-17
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_17_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1289
# 1.1302
# 1.1306
#
#
# 2016-04-19
# 2016-04-18
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_18_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1274
# 1.1293
# 1.1306
# 1.1332
#
#
# 2016-04-20
# 2016-04-19
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_19_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1304
# 1.132
# 1.1346
# 1.1367
# 1.1385
#
#
# 2016-04-21
# 2016-04-20
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_20_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1291
# 1.1303
# 1.1318
# 1.1345
# 1.1388
#
#
# 2016-04-22
# 2016-04-21
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_21_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.127
# 1.1315
# 1.1342
# 1.1364
# 1.1398
#
#
# 2016-04-23
# 2016-04-22
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_22_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1218
# 1.1241
# 1.1266
# 1.1288
# 1.1309
#
#
# 2016-04-24
# 2016-04-22
# 2016-04-22
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_22_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1218
# 1.1241
# 1.1266
# 1.1288
# 1.1309
#
#
# 2016-04-25
# 2016-04-24
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_24_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.122
# 1.1231
# 1.1235
#
#
# 2016-04-26
# 2016-04-25
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_25_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1224
# 1.1238
# 1.1249
# 1.1262
# 1.1278
#
#
# 2016-04-27
# 2016-04-26
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_26_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1257
# 1.1277
# 1.1299
# 1.1321
# 1.134
#
#
# 2016-04-28
# 2016-04-27
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_27_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1272
# 1.1288
# 1.1302
# 1.132
# 1.1336
# 1.135
# 1.1362
#
#
# 2016-04-29
# 2016-04-28
#
# S/R-levels already saved at ml_strat/clustering_return/ml_results_EURUSD_2016_04_28_0.15_500.csv
# Importing...
#
# -------------------------
# 	S/R-levels
# -------------------------
# 1.1296
# 1.1313
# 1.1327
# 1.1344
# 1.1368
#
#
# 2016-04-29 15:48:00, LONG POSITION CLOSE, 1.1445
# <img src="data:image/png;base64,...">
# Final Portfolio Value: 99853.7493
